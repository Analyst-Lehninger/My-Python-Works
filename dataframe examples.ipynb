# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Item' : ['Apple', 'Orange', 'Banana', 'Watermelon'],
    'Quantity': [12, 10, 100, 3],
    'Price' : [1, 2, 0.5, 9]
})

# %%
df
# Out:
#          Item  Quantity  Price
# 0       Apple        12    1.0
# 1      Orange        10    2.0
# 2      Banana       100    0.5
# 3  Watermelon         3    9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Item      4 non-null      object
#  1   Quantity  4 non-null      int64
#  2   Price     4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df.columns
# Out:
# Index(['Item', 'Quantity', 'Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.size
# Out:
# 12

# %%
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# Item         object
# Quantity      int64
# Price       float64
# dtype: object

# %%
df['Item']
# Out:
# 0         Apple
# 1        Orange
# 2        Banana
# 3    Watermelon
# Name: Item, dtype: object

# %%
df['Price']
# Out:
# 0    1.0
# 1    2.0
# 2    0.5
# 3    9.0
# Name: Price, dtype: float64

# %%
df['Quantity']
# Out:
# 0     12
# 1     10
# 2    100
# 3      3
# Name: Quantity, dtype: int64

# %%
df['Item'][0]
# Out:
# 'Apple'

# %%
df.loc[0]
# Out:
# Item        Apple
# Quantity       12
# Price         1.0
# Name: 0, dtype: object

# %%
df.loc[0:1]
# Out:
#      Item  Quantity  Price
# 0   Apple        12    1.0
# 1  Orange        10    2.0

# %%
df['Price'] > 5
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: Price, dtype: bool

# %%
lessthan20 = df['Quantity'] > 20

# %%
df[lessthan20]
# Out:
#      Item  Quantity  Price
# 2  Banana       100    0.5

# %%
df[df['Quantity'] > 20]
# Out:
#      Item  Quantity  Price
# 2  Banana       100    0.5

# %%
df['Total'] = df['Price'] * df['Quantity']
df
# Out:
#          Item  Quantity  Price  Total
# 0       Apple        12    1.0   12.0
# 1      Orange        10    2.0   20.0
# 2      Banana       100    0.5   50.0
# 3  Watermelon         3    9.0   27.0

# %%
total = df['Total']

# %%
total.min(), total.max()
# Out:
# (12.0, 50.0)

# %%
total.mean(), total.var(), total.std()
# Out:
# (27.25, 267.5833333333333, 16.357974609753292)

# %%
total.median()
# Out:
# 23.5

# %%
total.quantile(.25)
# Out:
# 18.0

# %%
total.quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    18.00
# 0.50    23.50
# 0.75    32.75
# Name: Total, dtype: float64

# %%
df.describe()
# Out:
#          Quantity     Price      Total
# count    4.000000  4.000000   4.000000
# mean    31.250000  3.125000  27.250000
# std     45.995471  3.966001  16.357975
# min      3.000000  0.500000  12.000000
# 25%      8.250000  0.875000  18.000000
# 50%     11.000000  1.500000  23.500000
# 75%     34.000000  3.750000  32.750000
# max    100.000000  9.000000  50.000000

# %%
# file = 'enter a file path in gdrive/onedrive'
# df = pd.read_csv(file)

# %%
df.head()
# Out:
#          Item  Quantity  Price  Total
# 0       Apple        12    1.0   12.0
# 1      Orange        10    2.0   20.0
# 2      Banana       100    0.5   50.0
# 3  Watermelon         3    9.0   27.0

# %%
df.head(2)
# Out:
#      Item  Quantity  Price  Total
# 0   Apple        12    1.0   12.0
# 1  Orange        10    2.0   20.0

# %%
# to open a CSV file (like excel) use these lines
# file = 'enter a file path in gdrive/onedrive'
# df = pd.read_csv(file)
